# %% [markdown]
# **Amrit Dhillon**
# **GSB545 Homework #2 Bagging and Boosting Main Notebook**

# %% [markdown]
# # Week 3 Kaggle Competition Homework #2

# %% [markdown]
# **#1 - #3 [DONE]**
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **#4** Find and upvote 3-4 notebooks or discussion posts that you find particularly insightful or you could realistically apply in your own modeling. Provide the URLs in your Homework document. Posting on discussion boards in Kaggle is a great way to get some exposure, but is not required.
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# **URL 1:** https://www.kaggle.com/code/tsunamazda/predicting-irrigation-need-baseline-xgboost
#
# **Reasoning for Choice:**
#
# - Provides easy to understand XGBoost baseline model and uses balanced accuracy (evaluation metric)
#
# - Shows the impact of key hyperparameters like learning_rate, max_depth, and n_estimators, which control how quickly the model learns and how complex each tree is
#
# - Contained ideas like feature importances and class weighting that I could apply to improve my models
#
# - Provides a clear baseline for how XGBoost performs without heavy tuning to compare against tuned model improvements later
#
#
# **URL 2:** https://www.kaggle.com/code/simarbirsinghsandhu/xgboost-optuna-gpu-cv-0-972
#
# **Reasoning for Choice:**
#
# - Shows a more optimized version of the XGBoost model with Stratified K-Fold cross validation and using Optuna for tuning which we just learned about
#
# - Helped understand how tuning learning rate, depth, and subsampling could impact performance
#
# - Shows how subsampling and regularization parameters help prevent overfitting in XGBoost by adding randomness and controlling model complexity
#
# - Highlights how boosting models like XGBoost can achieve strong performance without extensive feature engineering, relying on iterative error correction instead
#
#
# **URL 3:** https://www.kaggle.com/code/goggle3462/predicting-irrigation-need
#
# **Reasoning for Choice:**
#
# - Gives clear approach for Random Forest Classifier bagging model using a simple train/test split baseline
#
# - Useful to understand basic Random Forest hyperparameters like number of trees, depth, etc.
#
# - Showed clear way to handle categorical variables using encoding
#
#
# **URL 4:** https://www.kaggle.com/code/xjoannax88/ps-s6e4-irrigation-need-prediction
#
# **Reasoning for Choice:**
#
# - Included full preprocessing, encoding, and transformation pipeline in addition to cross validation for RandomForest
#
# - Demonstrates how Random Forest reduces variance by averaging many decision trees, which helped reinforce why it is a good baseline bagging model
#
# - Shows the impact of key hyperparameters like n_estimators and max_depth, which control model complexity and performance, giving me a starting point for tuning my own model
#
# - Uses feature subsampling within trees, which is a core idea in Random Forest that helps reduce overfitting
# ------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **#5** Create an EDA notebook for the competition. Do your initial EDA in that notebook and provide the URL in your Homework document.
#
# EDA Notebook URL: https://github.com/bigturtle13/GSB545/blob/main/Kaggle%20Playground%20Series%20Competition/Kaggle%20Homework%5BEDA%5D%20-%20Amrit%20Dhillon%20-%20therealbigturtle13.ipynb
#
#
# SweetViz EDA Report URL: https://github.com/bigturtle13/GSB545/blob/main/Kaggle%20Playground%20Series%20Competition/sweetviz_comparison_report.html
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **#6** Use two distinct modeling approaches, one bagging and one boosting. You may build other models, but the goal for the homework is to compare bagging and boosting approaches. You must submit at least one boosting and one bagging set of predictions to Kaggle (gets your submission workflow established). Consider exploring models we didn't cover in class. Make sure you are using cross-validation or another validation metric to improve your modeling. Do some tuning but don't spend hours and hours on it at this stage. Again, consider posting a public notebook on Kaggle (many people post only one or two notebooks out of many that they create).
#
# Bagging Notebook URL: https://github.com/bigturtle13/GSB545/blob/main/Kaggle%20Playground%20Series%20Competition/Kaggle%20Homework%5BBagging%5D%20-%20Amrit%20Dhillon%20-%20therealbigturtle13.ipynb
#
# Boosting Notebook URL: https://github.com/bigturtle13/GSB545/blob/main/Kaggle%20Playground%20Series%20Competition/Kaggle%20Homework%5BBoosting%5D%20-%20Amrit%20Dhillon%20-%20therealbigturtle13.ipynb
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **#7.** In your Kaggle Homework document provide:
#
# - URLs for the resources you upvoted on the competition site.  Discuss why you chose each--how will it help you improve your approach? [**PROVIDED ABOVE**]
#
# - Links to your EDA notebook and bagging and boosting notebook(s). [**PROVIDED ABOVE**]
#
# - Discuss your modeling approaches. What did you try? What worked well? What didn't work well? Were model improvements meaningful or small? Make sure to use performance metrics in your discussion. Also provide leaderboard scores for the models. A table might be useful for organizing the metrics and leaderboard scores. [**PROVIDED BELOW**]
#
# - How did boosting versus bagging compare for your work? [**PROVIDED BELOW**]

# %% [markdown]
# Discuss your modeling approaches. What did you try? What worked well? What didn't work well? Were model improvements meaningful or small? Make sure to use performance metrics in your discussion. Also provide leaderboard scores for the models. A table might be useful for organizing the metrics and leaderboard scores.
#
# - I tested two main ensemble approaches: Random Forest (bagging) and XGBoost (boosting), both evaluated using stratified CV with balanced accuracy due to class imbalance
#
# - The XGBoost model performed best, achieving a *CV score of 0.9694* and a *Kaggle leaderboard score of 0.9683* after hyperparameter tuning and some feature engineering inspired by notebooks that I looked through
#
# - The Random Forest model also performed well, with a *CV score of 0.9631* and a *Kaggle leaderboard score of 0.9606*, but it was consistently slightly worse than XGBoost
#
# - In my opinion, because it was so difficult to get model imrovements, the performance improvement from Random Forest to XGBoost (~0.007–0.008) was meaningful, showing that boosting provided better predictive power than bagging for this dataset
#
# - The gains from feature engineering were minimal but present, and so I kept them within my models
#
# - Using RandomizedSearchCV instead of full GridSearchCV helped reduce runtime significantly(it was taking forever before I used it) while still finding strong hyperparameters
#
# - One approach that did not go well was CatBoost, which caused repeated issues (library errors, file writing issues, and long runtimes). Because of this, I was unable to efficiently tune or evaluate it, so I focused on XGBoost instead. At some point I want to try it out again

# %%
import pandas as pd

results = pd.DataFrame({
    "Model": ["XGBoost", "Random Forest"],
    "Type": ["Boosting", "Bagging"],
    "Stratified K-Fold CV Score": [0.9694, 0.9631],
    "Kaggle Score": [0.9683, 0.9606]
})

results
# Out:
#            Model      Type  Stratified K-Fold CV Score  Kaggle Score
# 0        XGBoost  Boosting                      0.9694        0.9683
# 1  Random Forest   Bagging                      0.9631        0.9606

# %% [markdown]
# How did boosting versus bagging compare for your work?
#
# - In my notebooks, the boosting model (XGBoost) consistently outperformed the bagging model (Random Forest) in both cross-validation and Kaggle leaderboard performance in different iterations of both models
#
# - XGBoost achieved a *CV score of 0.9694* and a *Kaggle leaderboard score of 0.9683*, while Random Forest achieved a *CV score of 0.9631* and a *Kaggle leaderboard score of 0.9606*
#
# - The performance difference (~0.007–0.008) was meaningful but not drastic, indicating that both models were strong, but boosting provided a clear advantage
#
# - The improved performance of XGBoost is likely because of its ability to build trees sequentially and correct previous errors it made, whereas Random Forest builds trees independently and focuses on reducing variance
#
# - Overall, boosting proved to be more effective for this dataset, but the bagging model, Random Forest, still served as a strong and reliable baseline
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **#8.** What is your "phase 2" plan to improve your model performance? Note that although the leaderboard is fun to watch, you are not graded on it (and a shake up often occurs at the end!)
#
# - In "phase 2", now that I have established strong baselines for each of my bagging and boosting models, I would like to tune more hyperparameters like colsample_bytree, min_child_weight, and gamma to see if improvements can still be made
#
# - I would also like to further experiment with feature engineering, as it allowed me to make incremental improvements on my models. One type of engineered features I'd like to use specifically include interactions between weather variables like temperature and humidity or rainfall and soil moisture
#
# - Furthermore, although I experienced difficulty with other models like CatBoost this time around I would like to attempt using models like it again. I would like to see how CatBoost as well as LightGBM fare against XGBoost.
#
# - Apart from this I'm sure there are many improvements and iterations of my models to come. As I learn more things in class I will apply these concepts to my models, as well as anything I can find online.
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Week 4 Kaggle Competition Homework #3

# %% [markdown]
# **Link to GradientBoosint Notebook:** https://github.com/bigturtle13/GSB545/blob/main/Kaggle%20Playground%20Series%20Competition/Kaggle%20Homework%5BGradientBoosting%5D%20-%20Amrit%20Dhillon%20-%20therealbigturtle13.ipynb

# %% [markdown]
# **Discuss your modeling approaches.**
#
#  What did you try? What worked well? What didn't work well? Were model improvements meaningful or small? Make sure to use performance metrics in your discussion. Also provide leaderboard scores for the models. A table might be useful for organizing the metrics and leaderboard scores.

# %% [markdown]
# *What did you try?*
#
# - I tested multiple boosting models on the Kaggle dataset: XGBoost (prior), LightGBM, and HistGradientBoosting
#
#     - LightGBM: I chose it because it is a strong, efficient boosting method for large tabular datasets and usually gives a manageable runtime in my experience
#
#     - HistGradientBoosting: I chose it as a different boosting algorithm to compare against LightGBM while still keeping training practical on a large dataset in comparison to CatBoost and Adaboost which seemed like they were going to take much longer to complete running
#
# - I also attempted CatBoost again, but training time was too long for this workflow (about 20 minutes without completion), so I stopped and continued with faster models
#
# - I ran baseline CV models first, then tested at least three hyperparameter sets for both LightGBM and HistGradientBoosting
#
# - I reused engineered features from earlier work (Moisture_to_Heat_Ratio, Water_Availability_Index, Climate_Stress_Index) and added weather interaction features (Temp_x_Humidity, Rainfall_x_SoilMoisture, Sunlight_x_Temp)
#
# *What worked well?*
#
# - LightGBM responded best to tuning and feature engineering, and the best LightGBM hyperparameter settings reached CV balanced accuracy of around 0.962233
#
# - HistGradientBoosting also produced strong and stable scores around 0.961 and ran much faster than CatBoost (took 5-6 minutes average) so it served as a stable third option
#
# - The engineered weather interaction features appeared helpful for LightGBM (best score improved versus earlier LightGBM runs where I didn't use the engineered features)
#
# *Were model improvements meaningful or small?*
#
# - Improvements were incremental but present, not dramatic jumps when I tuned my models and added in engineered features in comparison to my baseline runs
#
# - LightGBM improved from earlier baseline-level of around 0.961271 to a best around 0.962233
#
# - HistGradientBoosting changes across parameter sets were also modest with the best tuned model achieving a balanced CV accuracy of 0.961408 compared to the baseline average of around 0.961034
#
# - Compared with my strongest prior XGBoost run (0.969418), newer models did not surpass it, so gains were meaningful for learning/tuning but not enough to replace the top model

# %% [markdown]
# **Leaderboard Scores**

# %%
import pandas as pd

manual_table = pd.DataFrame([
    {
        "Model": "XGBoost",
        "CV Balanced Accuracy": 0.9694,
        "Kaggle Public Score": 0.96830
    },
    {
        "Model": "LightGBM",
        "CV Balanced Accuracy": 0.962233,
        "Kaggle Public Score": 0.96045
    },
    {
        "Model": "HistGradientBoosting",
        "CV Balanced Accuracy": 0.961408,
        "Kaggle Public Score": 0.95763
    }
])


manual_table
# Out:
#                   Model  CV Balanced Accuracy  Kaggle Public Score
# 0               XGBoost              0.969400              0.96830
# 1              LightGBM              0.962233              0.96045
# 2  HistGradientBoosting              0.961408              0.95763

# %% [markdown]
# *How did the different models compare for your work?*
#
# - XGBoost was my best model (CV = 0.9694, Kaggle = 0.96830)
#
# - LightGBM was second (CV = 0.962233, Kaggle = 0.96045)
#
# - HistGradientBoosting was third (CV = 0.961408, Kaggle = 0.95763)
#
# - The model order was the same in both CV and Kaggle, so my CV testing matched real competition performance
